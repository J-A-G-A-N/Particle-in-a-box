# %%
# Required Libraries

import numpy as np                         # To create matrix
import matplotlib.pyplot as plt            # To Plot graph
from scipy.linalg import eigh_tridiagonal  # To find the eigenvalues and eigenvectors 
import math

# Constants
L = 1.0 # Maximum Length 
N = 100 # number of points in the grid
dx = L / (N - 1)  # grid spacing

x = dx * np.arange(N)

#Hermitian Matrix
diagonal = 2*np.ones(N) 
off_diagonal = -1 * np.ones(N - 1)
H = np.diag(diagonal) +  np.diag(off_diagonal, 1) + np.diag(off_diagonal, -1)



# Solve for energy eigenvalues and wavefunctions
E, psi = eigh_tridiagonal(diagonal , off_diagonal)




# Plot the first few solutions
for i in range(4):
    plt.plot(x, psi[:, i], label=f"n={i+1}, E={E[i]:.3f}")
plt.legend(loc='upper right')
plt.xlabel("x")
plt.ylabel("$\psi(x)$") # type: ignore
# plt.grid(True)
plt.title("Wavefunctions in an Infinite Potential Well")
plt.show()


for i in range(4):
    plt.plot(x, psi[:, i]**2, label=f"n={i+1}, E={E[i]:.3f}")
plt.legend(loc='upper right')
plt.xlabel("n")
plt.ylabel("$ \psi(x)^2$") # type: ignore
# plt.grid(True)
plt.title("probability density in an Infinite Potential Well")
plt.show()
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:33: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_52299/978355866.py:33: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$\psi(x)$") # type: ignore
# /tmp/ipykernel_52299/978355866.py:43: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$ \psi(x)^2$") # type: ignore

# %% [markdown]
# Energy plot

# %%
plt.scatter([0,1,2,3],     (E[0:4]))
plt.title("$E$ vs $n$ ")
plt.xlabel("$n$")
plt.ylabel("$E$")
plt.savefig('ENERGIES.png')
plt.show()

# %% [markdown]
# Final PLot

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

for i in range(4):
    axs[0, i].plot(x, psi[:, i], label=f"n={i+1}, E={E[i]:.3f}")
    axs[0, i].set_xlabel("x")
    axs[0, i].set_ylabel("$\psi(x)$")
    axs[0, i].set_title("Wavefunctions")
    axs[0, i].legend(loc='upper right')

    axs[1, i].plot(x, psi[:, i]**2, label=f"n={i+1}, E={E[i]:.3f}")
    axs[1, i].set_xlabel("x")
    axs[1, i].set_ylabel("$\psi(x)^2$")
    axs[1, i].set_title("Probability Density")
    axs[1, i].legend(loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_52299/2135677389.py:6: SyntaxWarning: invalid escape sequence '\p'
#   axs[0, i].set_ylabel("$\psi(x)$")
# /tmp/ipykernel_52299/2135677389.py:12: SyntaxWarning: invalid escape sequence '\p'
#   axs[1, i].set_ylabel("$\psi(x)^2$")
